# %% [markdown]
# # 뉴스 기사 크롤링 기반 감정 분석
#
# 이 노트북은 `src/main.py` 실행 후 생성된 CSV를 확인하고 분석 결과를 해석하기 위한 보고서용 노트북입니다.

# %%
import pandas as pd
from pathlib import Path

base_dir = Path('..')
processed_path = base_dir / 'data' / 'processed' / 'news_articles_sentiment.csv'
summary_path = base_dir / 'output' / 'tables' / 'sentiment_summary.csv'
keyword_path = base_dir / 'output' / 'tables' / 'keyword_frequency.csv'

# %%
df = pd.read_csv(processed_path)
display(df.head())

# %%
summary = pd.read_csv(summary_path)
display(summary)

# %%
keywords = pd.read_csv(keyword_path)
display(keywords.head(20))
